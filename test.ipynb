# %%
from radarsimpy import roc_pd, roc_snr
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.set_style('darkgrid')


snr = np.arange(-10, 30, 0.1)
pfa = np.array([1e-4])

# -10 dBsm
snr_mid = 10.1
range_mid = 121

range_coverage = range_mid*10**((snr_mid-snr)/40)

pd = roc_pd(pfa, snr, 1, 'Swerling 3')

plt.plot(range_coverage, pd, label='RCS -10 dBsm')

# -7 dBsm
snr_mid = 10.1
range_mid = 144

range_coverage = range_mid*10**((snr_mid-snr)/40)

pd = roc_pd(pfa, snr, 1, 'Swerling 3')

plt.plot(range_coverage, pd, label='RCS -7 dBsm')

# -3 dBsm
snr_mid = 10.1
range_mid = 181

range_coverage = range_mid*10**((snr_mid-snr)/40)

pd = roc_pd(pfa, snr, 1, 'Swerling 3')

plt.plot(range_coverage, pd, label='RCS -3 dBsm')

# 0 dBsm
snr_mid = 10.1
range_mid = 215

range_coverage = range_mid*10**((snr_mid-snr)/40)

pd = roc_pd(pfa, snr, 1, 'Swerling 3')

plt.plot(range_coverage, pd, label='RCS 0 dBsm')

# 5 dBsm
snr_mid = 10.1
range_mid = 287

range_coverage = range_mid*10**((snr_mid-snr)/40)

pd = roc_pd(pfa, snr, 1, 'Swerling 3')

plt.plot(range_coverage, pd, label='RCS 5 dBsm')

# 10 dBsm
snr_mid = 10.1
range_mid = 383

range_coverage = range_mid*10**((snr_mid-snr)/40)

pd = roc_pd(pfa, snr, 1, 'Swerling 3')

plt.plot(range_coverage, pd, label='RCS 10 dBsm')


plt.legend()

plt.xlabel('Range (m)')
plt.ylabel('Probability of detection')
plt.xlim(0, 600)
plt.tight_layout()

plt.savefig('FLR4+PDvsRange.svg')
